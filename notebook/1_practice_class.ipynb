# %%
import os
import re
from tifffile import imread
import napari
from napari.settings import get_settings
settings=get_settings()
settings.application.ipy_interactive=True
import tifffile
import xml.etree.ElementTree as ET
import pandas as pd
import zarr
from itertools import cycle
import numpy as np

# %%
from importlib import reload
import load_assess_image as load

# %%
import sys
sys.path.append('unify_biomarker_name')
from unify_biomarker_name import canonicalize, validate_panel

# %%
main_dir=rf'D:\thu\HTAN\images\NST'

# %%
cav_images = []
for i in os.listdir(main_dir):
    file_name=i.split("\\")[-1]
    image = load.AssessImage(main_dir, filename=file_name)

    # Find images with CAV1 channel
    if 'CAV1' in image.biomarker_channel:
        cav_images.append(file_name)

# %%
cav_images_ILC = []
main_dir_ilc=rf'D:\thu\HTAN\images\ILC\level_2'
for i in os.listdir(main_dir_ilc):
    file_name=i.split("\\")[-1]
    image = load.AssessImage(main_dir_ilc, filename=file_name)

    # Find images with CAV1 channel
    if 'CAV1' in image.biomarker_channel:
        cav_images_ILC.append(file_name)

# %%
file_name ='LSP12021-E8.ome.tif'
file_path=os.path.join(main_dir, file_name)
image_test=load.AssessImage(main_dir, filename=file_name )


channels_of_interest=['dna','Ki67','CD20','pRB','CD57','PDPN']
colors_list= ['green', 'bop blue', 'bop orange', 'bop purple', 'magenta', 'red', 'yellow','cyan','inferno']
channel_dict =image_test.find_biomarkers_of_interest(channels_of_interest)
image_test.view_images(channels_of_interest,resolution_level=0,colors_list=colors_list)
# Out:
# Processing File: LSP12021-E8.ome.tif
# ...
# Finding biomarkers: 100%|██████████| 40/40 [00:22<00:00,  1.77it/s]
# ...

# %%
dir(image_test)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_generate_flag',
#  'assess_single_image',
#  'biomarker_channel',
#  'channel_of_interest_data',
#  'find_biomarkers_of_interest',
#  'get_histogram',
#  'get_stats',
#  'loader',
#  'max_projection',
#  'unify_biomarker_name',
#  'view_images']
# WARNING: "Unable to open monitor interface to \\\\.\\DISPLAY193:" "Unknown error 0xe0000225."

# %%
disagree, dmean, fg= image_test.tile_disagreement(round_dna='dna(2)', tile=128, min_foreground=0.05)
# Out:
# Processing 59 x 59 tiles of size 128x128

# %%
file_name= cav_images_ILC[3]
file_path=os.path.join(main_dir_ilc, file_name)
image_test=load.AssessImage(main_dir_ilc, filename=file_name )


channels_of_interest=['dna(1)', 'CD45', 'aSMA', 'CD31','panCK','Vim','CAV1','CK7', 'CK8', 'CK18', 'CK19','pRB','Ki67','Cyclin_D1','PDPN', 'ColIV']
colors_list= ['green', 'bop blue', 'bop orange', 'bop purple', 'magenta', 'red', 'yellow','cyan','inferno']
channel_dict =image_test.find_biomarkers_of_interest(channels_of_interest)
# image_test.view_images(channels_of_interest,resolution_level=0,colors_list=colors_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_60748\2379633354.py in ?()
#       1 file_name= cav_images[3]
#       2 file_path=os.path.join(main_dir_ilc, file_name)
# ----> 3 image_test=load.AssessImage(main_dir_ilc, filename=file_name )
#       4
#       5
#       6 channels_of_interest=['dna(1)', 'CD45', 'aSMA', 'CD31','panCK','Vim','CAV1','CK7', 'CK8', 'CK18', 'CK19','pRB','Ki67','Cyclin_D1','PDPN', 'ColIV']
#
# r:\Thu\From_2026\6. Other\DL_Summer_2026\notebook\load_assess_image.py in ?(self, main_dir, filename)
#      41     def __init__(self,main_dir, filename):
# ---> 42         self.loader=OmeTifLoader(main_dir,filename)
#      43         self.unify_biomarker_name()
#
# r:\Thu\From_2026\6. Other\DL_Summer_2026\notebook\load_assess_image.py in ?(self, main_dir, filename)
#      23     def __init__(self,main_dir, filename):
# ...

# %%
image_test.view_images(['dna(1)' ,'dna(6)'],resolution_level=0)
# Out:
# Finding biomarkers: 100%|██████████| 54/54 [00:04<00:00, 11.45it/s]
# ...
