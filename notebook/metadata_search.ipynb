# %%
# METADATA

# %%
meta_data_ilc=pd.read_csv(rf"R:\Thu\From_2026\6. Other\DL_Summer_2026\data\ilc_table_data.tsv",sep="\t")
meta_data_ilc_patient=pd.read_csv(rf"R:\Thu\From_2026\6. Other\DL_Summer_2026\data\ilc_patient_ID_table_data.tsv",sep="\t")

# %%
meta_data_nst_patient=pd.read_csv(rF"R:\Thu\From_2026\6. Other\DL_Summer_2026\data\nst_patient_ID_table_data.tsv",sep='\t')

# %%
pd.Series(meta_data_nst[meta_data_nst['Filename'].str.contains('|'.join(nst_file))==False]['Synapse Id'].tolist()).to_csv('nst_file_names.txt', index=False)

# %%
from itables import show
show(meta_data_ilc_patient)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0e13f6ba_815e_4b01_9eea_260c5a268c6d"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...

# %%
meta_data_tumor = pd.concat([meta_data_ilc_patient,meta_data_nst_patient], ignore_index= True)

# %%
htan_cloud_metadata = pd.read_csv(rf"R:\Thu\From_2026\6. Other\DL_Summer_2026\data\htan-metadata-cloud-google.csv")

# %%
cols=['HTAN_Participant_ID','Breast_Carcinoma_Estrogen_Receptor_Status','Breast_Carcinoma_ER_Staining_Intensity','Breast_Carcinoma_HER2_Status','Breast_Carcinoma_PR_Staining_Intensity','Breast_Carcinoma_Progesteroner_Receptor_Status','Breast_Carcinoma_ER_Status_Percentage_Value','Breast_Carcinoma_PR_Status_Percentage_Value','Invasive_Lobular_Breast_Carcinoma_Histologic_Category']

# %%
htan_molecular_info = htan_cloud_metadata[cols]

# %%
mask = htan_molecular_info['HTAN_Participant_ID'].str.contains('HTA14', na=False)
htan_molecular_info = htan_molecular_info[mask]

# %%
mol_info=htan_molecular_info['HTAN_Participant_ID'].tolist()

# %%
tumor_info = meta_data_tumor['HTAN Participant ID'].tolist()

# %%
common_id=list(set((mol_info+tumor_info)))

# %%
meta_data_tumor=meta_data_tumor[meta_data_tumor['HTAN Participant ID'].isin(common_id)]

# %%
htan_molecular_info = htan_molecular_info[htan_molecular_info['HTAN_Participant_ID'].isin(common_id)]

# %%
meta_data_tumor=meta_data_tumor.rename(columns={'HTAN Participant ID': 'HTAN_Participant_ID'})

# %%
meta_data_tumor.set_index('HTAN_Participant_ID', inplace= True)

# %%
htan_molecular_info.set_index('HTAN_Participant_ID', inplace= True)

# %%
combined_meta_data=pd.concat([htan_molecular_info,meta_data_tumor], axis=1)

# %%
cols_less_na =['Breast_Carcinoma_ER_Status_Percentage_Value',
 'Breast_Carcinoma_PR_Status_Percentage_Value',
 'AJCC Clinical T',
 'AJCC Clinical N',
 'AJCC Clinical M',
 'Classification of Tumor',
 'Breast_Carcinoma_Estrogen_Receptor_Status',
 'Breast_Carcinoma_Progesteroner_Receptor_Status',
 'Breast_Carcinoma_ER_Staining_Intensity',
 'Breast_Carcinoma_PR_Staining_Intensity',
 'Breast_Carcinoma_HER2_Status',
 'Age at Diagnosis (years)',
 'Year Of Diagnosis',
 'Site of Resection or Biopsy',
 'Atlas Name',
 'Tumor Grade',
 'Progression or Recurrence',
 'Days to Last Known Disease Status',
 'Days to Last Followup',
 'Last Known Disease Status',
 'Days To Birth',
 'Morphology',
 'Tissue or Organ of Origin',
 'Gender',
 'Ethnicity',
 'Race',
 'Vital Status',
 'Primary Diagnosis',
 'Atlas ID',
 'Synapse ID',
 'Level']

combined_meta_data=combined_meta_data[cols_less_na]

# %%
nan_counts = combined_meta_data.isna().sum()
show(nan_counts[nan_counts > 0].sort_values(ascending=False))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_e583acb2_6647_4af3_9324_f085e80a90bf"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...
